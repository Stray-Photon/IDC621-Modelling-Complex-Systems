# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import scienceplots

N = 200                 #number of oscillators
K1 = 2
K2 = 3
K3 = 5                 #coupling strengths
t_span = (0, 50)
t_eval = np.linspace(*t_span, 2000)

# Lorentzian
gamma = 1
omega = gamma * np.tan(np.pi*(np.random.rand(N) - 0.5))

theta0 = np.random.uniform(0, 2*np.pi, N)

def kuramoto(t, theta, K):

    theta_i = theta[:, None]
    theta_j = theta[None, :]

    coupling = np.sum(np.sin(theta_j - theta_i), axis=1)

    return omega + (K/N) * coupling

sol1 = solve_ivp(kuramoto, t_span, theta0, t_eval=t_eval, args=(K1,))
sol2 = solve_ivp(kuramoto, t_span, theta0, t_eval=t_eval, args=(K2,))
sol3 = solve_ivp(kuramoto, t_span, theta0, t_eval=t_eval, args=(K3,))

theta1 = sol1.y
theta2 = sol2.y
theta3 = sol3.y

# %%
r1 = np.abs(np.mean(np.exp(1j*theta1), axis=0))
r2 = np.abs(np.mean(np.exp(1j*theta2), axis=0))
r3 = np.abs(np.mean(np.exp(1j*theta3), axis=0))

# %%
print(r1[-1], r2[-1], r3[-1])
# Out:
# 0.22823703812772733 0.5852399618346599 0.787370631364509

# %%
plt.style.use('science')
plt.figure(figsize=(4,3))
plt.plot(sol1.t, r1, label="K = 2")
plt.plot(sol2.t, r2, label="K = 3")
plt.plot(sol3.t, r3, label="K = 5")
plt.xlabel("t")
plt.ylabel("$r(t)$")
plt.ylim(0,1)
plt.legend(fontsize= 7,frameon=True)
plt.show()

# %%
K_values = np.linspace(0,8,20)
r_final = []

for K in K_values:

    sol = solve_ivp(kuramoto, t_span, theta0, t_eval=t_eval, args=(K,))
    theta = sol.y
    r = np.abs(np.mean(np.exp(1j*theta), axis=0))

    r_final.append(np.mean(r[-200:]))

plt.figure(figsize=(4,3))
plt.plot(K_values, r_final,'o-', color='purple')
plt.xlabel("k")
plt.ylabel("r")
plt.ylim(0,1)
plt.show()

# %%
theta_final_phases = theta[:,-1]

plt.figure(figsize=(4,3))
plt.scatter(np.cos(theta_final_phases), np.sin(theta_final_phases), color = 'purple')
circle = plt.Circle((0,0),1,fill=False)
plt.gca().add_patch(circle)
plt.gca().set_aspect('equal')
plt.show()

# %%
K_test = [2, 3, 5]

fig, axes = plt.subplots(1,3, figsize=(7,4))

for i, K in enumerate(K_test):

    sol = solve_ivp(kuramoto, t_span, theta0, t_eval=t_eval, args=(K,))

    theta = sol.y
    theta_final = theta[:,-1]

    ax = axes[i]
    ax.scatter(np.cos(theta_final), np.sin(theta_final), s=10, color='purple')
    circle = plt.Circle((0,0),1,fill=False)
    ax.add_patch(circle)
    ax.set_aspect('equal')
    ax.set_title(f"K = {K}")

plt.tight_layout()
plt.show()
